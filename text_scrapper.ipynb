# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

# %%
from urllib.request import urlopen

# url 입력은 추후에 엑셀에서 입력 받는 것으로 수정해야 함
url = ''
html = urlopen(url)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\anaconda3\Lib\urllib\request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File ~\anaconda3\Lib\http\client.py:1336, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1335 """Send a complete request to the server."""
# -> 1336 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1382, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1381     body = _encode(body, 'body')
# -> 1382 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#
# File ~\anaconda3\Lib\http\client.py:1035, in HTTPConnection.send(self, data)
#    1034 if self.auto_open:
# -> 1035     self.connect()
#    1036 else:
#
# File ~\anaconda3\Lib\http\client.py:1477, in HTTPSConnection.connect(self)
#    1475     server_hostname = self.host
# -> 1477 self.sock = self._context.wrap_socket(self.sock,
#    1478                                       server_hostname=server_hostname)
#
# File ~\anaconda3\Lib\ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File ~\anaconda3\Lib\ssl.py:1042, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1041                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1042             self.do_handshake()
#    1043 except:
#
# File ~\anaconda3\Lib\ssl.py:1320, in SSLSocket.do_handshake(self, block)
#    1319         self.settimeout(None)
# -> 1320     self._sslobj.do_handshake()
#    1321 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[3], line 5
#       3 # url 입력은 추후에 엑셀에서 입력 받는 것으로 수정해야 함
#       4 url = 'http://www.lotteon.com/p/display/main/lotteon'
# ----> 5 html = urlopen(url)
#
# File ~\anaconda3\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~\anaconda3\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File ~\anaconda3\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File ~\anaconda3\Lib\urllib\request.py:553, in OpenerDirector.error(self, proto, *args)
#     551     http_err = 0
#     552 args = (dict, proto, meth_name) + args
# --> 553 result = self._call_chain(*args)
#     554 if result:
#     555     return result
#
# File ~\anaconda3\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~\anaconda3\Lib\urllib\request.py:745, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     742 fp.read()
#     743 fp.close()
# --> 745 return self.parent.open(new, timeout=req.timeout)
#
# File ~\anaconda3\Lib\urllib\request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
#     517 # post-process response
#     518 meth_name = protocol+"_response"
#
# File ~\anaconda3\Lib\urllib\request.py:532, in OpenerDirector._open(self, req, data)
#     529     return result
#     531 protocol = req.type
# --> 532 result = self._call_chain(self.handle_open, protocol, protocol +
#     533                           '_open', req)
#     534 if result:
#     535     return result
#
# File ~\anaconda3\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~\anaconda3\Lib\urllib\request.py:1392, in HTTPSHandler.https_open(self, req)
#    1391 def https_open(self, req):
# -> 1392     return self.do_open(http.client.HTTPSConnection, req,
#    1393                         context=self._context)
#
# File ~\anaconda3\Lib\urllib\request.py:1347, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1344         h.request(req.get_method(), req.selector, req.data, headers,
#    1345                   encode_chunked=req.has_header('Transfer-encoding'))
#    1346     except OSError as err: # timeout error
# -> 1347         raise URLError(err)
#    1348     r = h.getresponse()
#    1349 except:
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)>

# %%
bs_obj = BeautifulSoup(html, "html.parser")

# %%
print(bs_obj)

# %% [markdown]
# ## 특정 키워드를 포함하는 요소 찾기

# %%
keyword = '' # 찾을 키워드
keyword_element = bs_obj.find(string=lambda text: keyword in text if text else False)

# %%
print(keyword_element)
# Out:
# {"props":{"pageProps":{"user_agent":"Python-urllib/3.12","user_locale":{"language":"ko","country":"KR","currency":"KRW"},"currency_meta":{"currency":"KRW","decimal":0,"converted_rate":1,"display_currency":"원","is_currency_prefix":false},"is_pdp":false,"ZIGZAGUUID":null,"_nextI18Next":{"initialLocale":"ko"},"ROUTES_TITLE_DATA":{"":"","-":"-","회원님을 위한 혜택":"회원님을 위한 혜택","혜택정보":"혜택정보","쿠폰할인":"쿠폰할인","쿠폰적용":"쿠폰적용","중복쿠폰":"중복쿠폰","배송비 쿠폰":"배송비 쿠폰","쿠폰받기":"쿠폰받기","쿠폰":"쿠폰","쿠폰등록":"쿠폰등록","쿠폰상세":"쿠폰상세","쿠폰검색":"쿠폰검색","주문/결제":"주문/결제","결제":"결제","문의 내역":"문의 내역","문의하기":"문의하기","주문 상세":"주문 상세","취소 정보":"취소 정보","반품 정보":"반품 정보","교환 정보":"교환 정보","교환불가 안내":"교환불가 안내","배송연기 안내":"배송연기 안내","배송보류 안내":"배송보류 안내","구매확정":"구매확정","배송지 변경":"배송지 변경","미입금 주문 취소":"미입금 주문 취소","주문 취소":"주문 취소","주문 교환":"주문 교환","주문 반품":"주문 반품","교환 요청":"교환 요청","결제 정보":"결제 정보","계좌 간편결제":"계좌 간편결제","간편결제 등록":"간편결제 등록","결제 비밀번호 변경":"결제 비밀번호 변경","간편결제 관리":"간편결제 관리","포인트":"포인트","환불계좌":"환불계좌","배송 현황":"배송 현황","반품 현황":"반품 현황","공지사항":"공지사항","공유 리워드 메인":"공유 리워드 메인","공유 리워드 신청하기":"공유 리워드 신청하기","공유 리워드":"공유 리워드","리워드 지급 정보":"리워드 지급 정보","공유 리워드 적립현황 리스트":"공유 리워드 적립현황 리스트","내 리워드 등급":"내 리워드 등급","SNS 채널 인증":"SNS 채널 인증","SNS 채널 인증 이미지":"SNS 채널 인증 이미지","공유 리워드 적립 상세":"공유 리워드 적립 상세","공유 리워드 소개":"공유 리워드 소개","오픈 프로모션":"오픈 프로모션","사용자 약관":"사용자 약관","본인인증":"본인인증","알림":"알림","알림 설정":"알림 설정","카카오톡 문의":"카카오톡 문의","네이버톡톡 문의":"네이버톡톡 문의","이용약관":"이용약관","개인정보취급방침":"개인정보취급방침","마이픽쿠폰":"마이픽쿠폰","내 마이픽쿠폰":"내 마이픽쿠폰","마이픽쿠폰 선택":"마이픽쿠폰 선택","마이픽쿠폰 샵 검색":"마이픽쿠폰 샵 검색","마이픽쿠폰 튜토리얼":"마이픽쿠폰 튜토리얼","마이픽쿠폰 배너 이미지":"마이픽쿠폰 배너 이미지","포토리뷰":"포토리뷰","공유 리워드 콘텐츠 제출":"공유 리워드 콘텐츠 제출","리뷰작성":"리뷰작성","리뷰작성완료":"리뷰작성완료","사업자 정보 확인":"사업자 정보 확인","체형정보":"체형정보","맞춤정보 수집 및 이용 동의":"맞춤정보 수집 및 이용 동의","배송지 목록":"배송지 목록","배송지 추가":"배송지 추가","배송지 수정":"배송지 수정","우편번호 검색":"우편번호 검색","입금방법":"입금방법","장바구니":"장바구니","오늘의 혜택":"오늘의 혜택","랜덤박스":"랜덤박스","출석체크":"출석체크","수거 현황":"수거 현황","래플":"래플","응모결과":"응모결과","응모완료":"응모완료","당첨자 전체보기":"당첨자 전체보기","래플 응모현황":"래플 응모현황","마일리지":"마일리지","마일리지 사용법":"마일리지 사용법","뷰티":"뷰티","뷰티 신상":"뷰티 신상","뷰티 프리퀀시":"뷰티 프리퀀시","브랜드":"브랜드","전체 브랜드":"전체 브랜드","브랜드 CLP":"브랜드 CLP","톡라운지":"톡라운지","개인통관 고유부호 조회/발급":"개인통관 고유부호 조회/발급","리뷰":"리뷰","구매 전 이 상품 어때요?":"구매 전 이 상품 어때요?","직잭 랭킹상품 최대 할인 중!":"직잭 랭킹상품 최대 할인 중!","지그재그 체험단":"지그재그 체험단","내 체험단 활동":"내 체험단 활동","멤버십":"멤버십","리뷰어 랭킹":"리뷰어 랭킹","직진배송":"직진배송","체험단 신청":"체험단 신청","신청완료":"신청완료"},"_sentryTraceData":"fa32dee401f047ddb3963ce829ba9bd7-bfc95bcec4054d63-0","_sentryBaggage":"sentry-environment=production,sentry-release=a33e8dfeeac75932c5e420ce11879a350e945249,sentry-public_key=22c08599cc4c8863c0c9107b5173d238,sentry-trace_id=fa32dee401f047ddb3963ce829ba9bd7,sentry-sample_rate=0.0001,sentry-transaction=%2F,sentry-sampled=false","dehydratedState":{"mutations":[],"queries":[{"state":{"data":{"id":"7","position":0,"type":"UX_IMAGE_BANNER_GROUP","aspect_ratio":4.699999809265137,"is_auto_rolling":true,"update_interval":60,"item_list":[{"id":"25937","image_url":"https://cf.image-farm.s.zigzag.kr/original/cms/2024/09/26/202409260832211338_073084.jpg?width=1029\u0026height=1029\u0026quality=100\u0026format=webp\u0026transparent=true","landing_url":"zigzag://open/simple_browser?url=https://store.zigzag.kr/events/36e9dd4b-f999-4dbb-873e-168826e22ffd","position":0,"main_title_first":"","main_title_second":"","sub_title":null,"log":"banner_id=25937\u0026item_position=0"},{"id":"25399","image_url":"https://cf.image-farm.s.zigzag.kr/original/cms/2024/09/13/202409130813401179_036022.jpg","landing_url":"zigzag://open/simple_browser?url=https%3A%2F%2Fstore.zigzag.kr%2Fevents%2F0230f160-c0b6-47b1-bbd0-65b8a38ee81f","position":1,"main_title_first":"백 \u0026 슈즈 페스타","main_title_second":"최대 72% 할인","sub_title":"매일 오후 8시 선착순 쿠폰 발급","log":"banner_id=25399\u0026item_position=1"},{"id":"25598","image_url":"https://cf.image-farm.s.zigzag.kr/original/cms/2024/09/20/202409200201203707_059634.jpg","landing_url":"zigzag://open/simple_browser?url=https://store.zigzag.kr/events/6793d08b-16cd-47cc-980c-e1ad1c577fc8","position":2,"main_title_first":"직잭 인기 쇼핑몰","main ...

# %%
if keyword_element:
    # 부모 요소를 순차적으로 올라가면서 세 번째 div를 찾기
    current_element = keyword_element.parent
    div_count = 0

    while current_element and div_count < 4:
        if current_element.name == 'div':
            div_count += 1
        current_element = current_element.parent

    if current_element:
        print(current_element.prettify())
    else:
        print("없음");
else:
    print(f"`{keyword}`를 포함한 요소를 찾을 수 없음")
# Out:
# 없음
